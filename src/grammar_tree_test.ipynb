# %%
from nodes import Root, Div, Clones, Clone, Conn, Conns
from visualizer.individualvisualizer import IndividualVisualizer
from ea import EA
import pdb
#pdb.set_trace()
ea = EA(1)
ea.load_config('../settings/bipedal_default.json')
r1 = Root(ea.config)
r1.generate()
r2 = Root(ea.config)
r2.generate()

# %%
for i in range(100):
    r1.insert_at_div(Div)
    for j in range (10):
        r1.insert_at_list(Conn)

# %%
r1.compile()
v1 = IndividualVisualizer(r1)
v1.draw_tree()

# %%
import numpy as np
r1.compile()
nn = r1.execute()
nn.compile()
nn.step(np.ones(24))
# Out:
# array([ 1.        ,  0.99999998, -1.        ,  1.        ])

# %%
r1.execute()
v1.draw_nn()
